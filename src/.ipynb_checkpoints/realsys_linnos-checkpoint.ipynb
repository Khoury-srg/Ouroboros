# %%
import importlib
from numpy.core.numeric import Inf
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
import numpy as np
from NNet.utils.writeNNet import writeNNet
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as patches
import time
import importlib
import models
import datasets
import math
import utils
from utils import *
import tasks
# Out:
# WARNING: method definition for is_polyhedral at /home/mlsys23/.julia/packages/LazySets/HlinV/src/LazyOperations/Complement.jl:53 declares type variable N but does not use it.
# WARNING: method definition for convert at /home/mlsys23/.julia/packages/LazySets/HlinV/src/convert.jl:179 declares type variable N but does not use it.
# WARNING: method definition for issubset at /home/mlsys23/.julia/packages/LazySets/HlinV/src/ConcreteOperations/issubset.jl:609 declares type variable N but does not use it.

# %%
def to_device(data, device):
    return tuple(tensor.to(device) for tensor in data) if isinstance(data, tuple) else data.to(device)
def test(model, data, batch_size, compute_loss, verbose=False, compute_error=False):
    dataloader = DataLoader(data, batch_size=batch_size)
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    digit_size, digit_correct = 0, 0
    positive = 0
    with torch.no_grad():
        for X, y in dataloader:
            X = to_device(X, "cuda")
            y = to_device(y, "cuda")
            if compute_error:
                acc_cnt, loss = compute_loss(model, X, y)
                test_loss += loss.cpu().item() if torch.is_tensor(loss) else loss
                correct += acc_cnt.cpu().item() if torch.is_tensor(acc_cnt) else acc_cnt
    if not compute_error:
        return None, None
    test_loss /= num_batches
    acc = correct * 1. / size
    if verbose:
        print(f"Test Error: \n Accuracy: {(100*acc):>0.1f}%, Avg loss: {test_loss:>8f} \n")

    return acc, test_loss
    
def accuracy_comparison(task_class, time_out, verified):

    training_data = datasets.LinnosDataset("../data/linnos/linnos.csv", test=False)
    print(training_data)
    task = task_class(add_counterexample = verified, incremental_training = verified, batch_counterexample = verified, early_rejection = verified, time_out=time_out) # wo finetune
    task.load_model("../model/"+task.save_name+".pth")

    print(task.save_name)
    print("data size: ", len(training_data))
    param_size = 0
    for param in task.model.parameters():
        param_size += param.nelement() * param.element_size()
    print('model size: {:.3f}KB'.format(param_size / 1024))
    def eval_loss(model, X, y):
        # normal_X, counter_X = X
        # normal_y, counter_y = y
        normal_X = X
        normal_y = y
        normal_acc_cnt, normal_loss = task.compute_normal_loss(model, normal_X, normal_y)
        return normal_acc_cnt, normal_loss

    task.model = task.model.to("cuda")
    task.model.eval()

    ### latency ###
    batch_size=1
    start = time.time()
    acc, loss = test(task.model, training_data, batch_size, eval_loss, compute_error=False)
    end = time.time()
    print("latency time (us): {:.5f}".format((end - start)/len(training_data)*1e6))
    # print("accuracy: {:.9f}".format(acc))
    # print("l2 error: {:.9f}".format(loss))
    
    ### throughput ###
    start = time.time()
    rep_times = 100
    batch_size = len(training_data)
    for t in range(rep_times):
        acc, loss = test(task.model, training_data, batch_size, eval_loss, compute_error=False)
    end = time.time()
    print("throughput: {:.5f}".format(len(training_data)/((end - start)/rep_times)))

    acc, loss = test(task.model, training_data, batch_size, eval_loss, compute_error=True)
    print("accuracy: {:.9f}".format(acc))
    print("l2 error: {:.9f}".format(loss))
    
accuracy_comparison(tasks.LinnosTask, 300, False)
# Out:
# <datasets.LinnosDataset object at 0x7ff78a285c50>
# LinnosTask00000-1_300
# data size:  47895
# model size: 365.629KB
# latency time (us): 88.77328
# throughput: 158423.67159
# accuracy: 0.998475833
# l2 error: 0.000139140

# %%
accuracy_comparison(tasks.LinnosTask, 300, True)
# Out:
# <datasets.LinnosDataset object at 0x7ff78a251da0>
# LinnosTask11110-1_300
# data size:  47895
# model size: 365.629KB
# latency time (us): 76.53733
# throughput: 170820.04905
# accuracy: 0.998308801
# l2 error: 0.000080312

# %%
def train(model, data, batch_size, compute_loss, verbose=False):
    device = "cuda"
    dataloader = DataLoader(data, batch_size=batch_size, shuffle=True)
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, correct = 0, 0
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
    for batch, (X, y) in enumerate(dataloader):
        X = to_device(X, device)
        y = to_device(y, device)
        acc_cnt, loss = compute_loss(model, X, y)
        # print(acc_cnt, "/", len(X))
        correct += acc_cnt.cpu().item() if torch.is_tensor(acc_cnt) else acc_cnt
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        train_loss += loss.cpu().item() if torch.is_tensor(loss) else loss
        # if verbose and batch % 10 == 0:
        #     loss, current = loss.item(), batch * len(X)
        #     print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    train_loss /= num_batches
    acc = correct * 1. / size
    if verbose:
        print(f"Train Error: \n Accuracy: {(100*acc):>0.1f}%, Avg loss: {train_loss:>8f} \n")
    return acc, train_loss

def baseline():
    model = models.FC(1, 9, 256, 2)
    loss_fn = nn.CrossEntropyLoss()
    def compute_loss(model, x, y):
        y = y.squeeze(dim=1)
        pred = model(x)
        # print(pred)
        # print(y)
        # print(pred.argmax(1))
        acc_cnt = (pred.argmax(1) == y).type(torch.float).sum().item()
        # print(acc_cnt)
        # assert False
        loss = loss_fn(pred, y)
        return acc_cnt, loss

    training_data = datasets.LinnosDataset("../data/linnos/linnos.csv", test=False)
    print(np.shape(training_data.xs))
    print(np.max(training_data.ys))
    print(np.min(training_data.ys))
    print(np.mean(training_data.ys))
    print(np.median(training_data.ys))
    threshold = np.median(training_data.ys)
    training_data.ys = training_data.ys > threshold
    training_data.ys = training_data.ys.astype(int)
    for ep in range(1000):
        print("epoch: ", ep)
        acc, train_loss = train(model, training_data, 5000, compute_loss, verbose=True)

baseline()
# Out:
# (47895, 9)
# 1.0
# 0.0
# 0.00701667
# 0.00058624975
# epoch:  0
# Train Error:
#  Accuracy: 64.7%, Avg loss: 0.673843
#
# epoch:  1
# Train Error:
#  Accuracy: 66.7%, Avg loss: 0.650256
#
# epoch:  2
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.629490
#
# epoch:  3
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.610861
#
# epoch:  4
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.595387
#
# epoch:  5
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.585166
#
# epoch:  6
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.577915
#
# epoch:  7
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.573539
#
# epoch:  8
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.570485
#
# epoch:  9
# Train Error:
#  Accuracy: 66.8%, Avg loss: 0.569546
#
# epoch:  10
# Train Error:
#  Accuracy: 67.0%, Avg loss: 0.567674
#
# epoch:  11
# Train Error:
#  Accuracy: 67.1%, Avg loss: 0.566317
#
# epoch:  12
# Train Error:
#  Accuracy: 67.2%, Avg loss: 0.564824
#
# epoch:  13
# Train Error:
#  Accuracy: 67.2%, Avg loss: 0.563736
#
# epoch:  14
# Train Error:
#  Accuracy: 67.2%, Avg loss: 0.562219
#
# epoch:  15
# Train Error:
#  Accuracy: 67.3%, Avg loss: 0.561309
#
# epoch:  16
# Train Error:
#  Accuracy: 67.3%, Avg loss: 0.560439
#
# epoch:  17
# Train Error:
#  Accuracy: 67.4%, Avg loss: 0.559152
#
# epoch:  18
# Train Error:
#  Accuracy: 67.4%, Avg loss: 0.558244
#
# epoch:  19
# Train Error:
#  Accuracy: 67.5%, Avg loss: 0.557227
#
# epoch:  20
# Train Error:
#  Accuracy: 67.5%, Avg loss: 0.556977
#
# epoch:  21
# Train Error:
#  Accuracy: 67.5%, Avg loss: 0.555790
#
# epoch:  22
# Train Error:
#  Accuracy: 67.6%, Avg loss: 0.555583
#
# epoch:  23
# Train Error:
#  Accuracy: 67.6%, Avg loss: 0.554517
#
# epoch:  24
# Train Error:
#  Accuracy: 67.6%, Avg loss: 0.554562
#
# epoch:  25
# Train Error:
#  Accuracy: 67.6%, Avg loss: 0.553698
#
# epoch:  26
# Train Error:
#  Accuracy: 67.6%, Avg loss: 0.552542
#
# epoch:  27
# Train Error:
#  Accuracy: 67.7%, Avg loss: 0.553547
#
# epoch:  28
# Train Error:
#  Accuracy: 67.7%, Avg loss: 0.553424
#
# epoch:  29
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.552796
#
# epoch:  30
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.552179
#
# epoch:  31
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.552007
#
# epoch:  32
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.551870
#
# epoch:  33
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.552239
#
# epoch:  34
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.551779
#
# epoch:  35
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.551238
#
# epoch:  36
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.551459
#
# epoch:  37
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.551773
#
# epoch:  38
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.550900
#
# epoch:  39
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.551358
#
# epoch:  40
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.551322
#
# epoch:  41
# Train Error:
#  Accuracy: 67.8%, Avg loss: 0.551328
#
# epoch:  42
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550807
#
# epoch:  43
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.551284
#
# epoch:  44
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550616
#
# epoch:  45
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550608
#
# epoch:  46
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550633
#
# epoch:  47
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550283
#
# epoch:  48
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549872
#
# epoch:  49
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.550509
#
# epoch:  50
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550273
#
# epoch:  51
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550734
#
# epoch:  52
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.550062
#
# epoch:  53
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.550117
#
# epoch:  54
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.549982
#
# epoch:  55
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549541
#
# epoch:  56
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549571
#
# epoch:  57
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.550136
#
# epoch:  58
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549789
#
# epoch:  59
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549526
#
# epoch:  60
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.549302
#
# epoch:  61
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549882
#
# epoch:  62
# Train Error:
#  Accuracy: 67.9%, Avg loss: 0.549974
#
# epoch:  63
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549534
#
# epoch:  64
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549743
#
# epoch:  65
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549815
#
# epoch:  66
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549498
#
# epoch:  67
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549621
#
# epoch:  68
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549297
#
# epoch:  69
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549637
#
# epoch:  70
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.549394
#
# epoch:  71
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.549132
#
# epoch:  72
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.549206
#
# epoch:  73
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.549071
#
# epoch:  74
# Train Error:
#  Accuracy: 68.0%, Avg loss: 0.548830
#
# epoch:  75
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548561
#
# epoch:  76
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548907
#
# epoch:  77
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548846
#
# epoch:  78
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.548700
#
# epoch:  79
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548215
#
# epoch:  80
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548359
#
# epoch:  81
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548274
#
# epoch:  82
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548572
#
# epoch:  83
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.547959
#
# epoch:  84
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547990
#
# epoch:  85
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.548031
#
# epoch:  86
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548131
#
# epoch:  87
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.548196
#
# epoch:  88
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548211
#
# epoch:  89
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.548304
#
# epoch:  90
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547786
#
# epoch:  91
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.547929
#
# epoch:  92
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.548510
#
# epoch:  93
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547381
#
# epoch:  94
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.548091
#
# epoch:  95
# Train Error:
#  Accuracy: 68.1%, Avg loss: 0.547687
#
# epoch:  96
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547553
#
# epoch:  97
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547163
#
# epoch:  98
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547427
#
# epoch:  99
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547667
#
# epoch:  100
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547186
#
# epoch:  101
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547176
#
# epoch:  102
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.547209
#
# epoch:  103
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.547095
#
# epoch:  104
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.547488
#
# epoch:  105
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.547188
#
# epoch:  106
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.547250
#
# epoch:  107
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.546492
#
# epoch:  108
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.546439
#
# epoch:  109
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.546200
#
# epoch:  110
# Train Error:
#  Accuracy: 68.2%, Avg loss: 0.546698
#
# epoch:  111
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.546563
#
# epoch:  112
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.546582
#
# epoch:  113
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.546856
#
# epoch:  114
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.546337
#
# epoch:  115
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.546229
#
# epoch:  116
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.545590
#
# epoch:  117
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.545928
#
# epoch:  118
# Train Error:
#  Accuracy: 68.3%, Avg loss: 0.546168
#
# epoch:  119
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545953
#
# epoch:  120
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.546792
#
# epoch:  121
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.546220
#
# epoch:  122
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545694
#
# epoch:  123
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545632
#
# epoch:  124
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.545950
#
# epoch:  125
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.545638
#
# epoch:  126
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.546167
#
# epoch:  127
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.545767
#
# epoch:  128
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545628
#
# epoch:  129
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.545446
#
# epoch:  130
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.545946
#
# epoch:  131
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544846
#
# epoch:  132
# Train Error:
#  Accuracy: 68.4%, Avg loss: 0.545281
#
# epoch:  133
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545009
#
# epoch:  134
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545524
#
# epoch:  135
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545394
#
# epoch:  136
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545390
#
# epoch:  137
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.545683
#
# epoch:  138
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544672
#
# epoch:  139
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544984
#
# epoch:  140
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544887
#
# epoch:  141
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544452
#
# epoch:  142
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544654
#
# epoch:  143
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544900
#
# epoch:  144
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.545096
#
# epoch:  145
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544897
#
# epoch:  146
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544798
#
# epoch:  147
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544963
#
# epoch:  148
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544710
#
# epoch:  149
# Train Error:
#  Accuracy: 68.5%, Avg loss: 0.544916
#
# epoch:  150
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543881
#
# epoch:  151
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544534
#
# epoch:  152
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544486
#
# epoch:  153
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.543878
#
# epoch:  154
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544579
#
# epoch:  155
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544282
#
# epoch:  156
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.544542
#
# epoch:  157
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544676
#
# epoch:  158
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544046
#
# epoch:  159
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.543540
#
# epoch:  160
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.543994
#
# epoch:  161
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.544288
#
# epoch:  162
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.544437
#
# epoch:  163
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.544023
#
# epoch:  164
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543816
#
# epoch:  165
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544084
#
# epoch:  166
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.543735
#
# epoch:  167
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544384
#
# epoch:  168
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543528
#
# epoch:  169
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.543748
#
# epoch:  170
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.543815
#
# epoch:  171
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543696
#
# epoch:  172
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.544344
#
# epoch:  173
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.544305
#
# epoch:  174
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543232
#
# epoch:  175
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543369
#
# epoch:  176
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543537
#
# epoch:  177
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.543455
#
# epoch:  178
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543415
#
# epoch:  179
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.542577
#
# epoch:  180
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543539
#
# epoch:  181
# Train Error:
#  Accuracy: 68.6%, Avg loss: 0.543626
#
# epoch:  182
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.543776
#
# epoch:  183
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543810
#
# epoch:  184
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543398
#
# epoch:  185
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542881
#
# epoch:  186
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542448
#
# epoch:  187
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543038
#
# epoch:  188
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543252
#
# epoch:  189
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.542795
#
# epoch:  190
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543498
#
# epoch:  191
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543177
#
# epoch:  192
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.543327
#
# epoch:  193
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542664
#
# epoch:  194
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.543131
#
# epoch:  195
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542604
#
# epoch:  196
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543226
#
# epoch:  197
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542905
#
# epoch:  198
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.543345
#
# epoch:  199
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542914
#
# epoch:  200
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542544
#
# epoch:  201
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.543524
#
# epoch:  202
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.543232
#
# epoch:  203
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542767
#
# epoch:  204
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542741
#
# epoch:  205
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542712
#
# epoch:  206
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.543021
#
# epoch:  207
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.543155
#
# epoch:  208
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542615
#
# epoch:  209
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542578
#
# epoch:  210
# Train Error:
#  Accuracy: 68.7%, Avg loss: 0.542873
#
# epoch:  211
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542568
#
# epoch:  212
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542628
#
# epoch:  213
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542233
#
# epoch:  214
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542528
#
# epoch:  215
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542774
#
# epoch:  216
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.543220
#
# epoch:  217
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542366
#
# epoch:  218
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542483
#
# epoch:  219
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542930
#
# epoch:  220
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541939
#
# epoch:  221
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542906
#
# epoch:  222
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542373
#
# epoch:  223
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542951
#
# epoch:  224
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.541637
#
# epoch:  225
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542669
#
# epoch:  226
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.543615
#
# epoch:  227
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541763
#
# epoch:  228
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542158
#
# epoch:  229
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.542568
#
# epoch:  230
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541495
#
# epoch:  231
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542019
#
# epoch:  232
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541521
#
# epoch:  233
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542913
#
# epoch:  234
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542035
#
# epoch:  235
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542433
#
# epoch:  236
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541444
#
# epoch:  237
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542394
#
# epoch:  238
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.542078
#
# epoch:  239
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.541491
#
# epoch:  240
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.542508
#
# epoch:  241
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541992
#
# epoch:  242
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541407
#
# epoch:  243
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.541863
#
# epoch:  244
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541579
#
# epoch:  245
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.541551
#
# epoch:  246
# Train Error:
#  Accuracy: 68.8%, Avg loss: 0.541608
#
# epoch:  247
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541751
#
# epoch:  248
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541591
#
# epoch:  249
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541411
#
# epoch:  250
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541565
#
# epoch:  251
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541822
#
# epoch:  252
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541602
#
# epoch:  253
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541927
#
# epoch:  254
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541554
#
# epoch:  255
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.540957
#
# epoch:  256
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541025
#
# epoch:  257
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541421
#
# epoch:  258
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541242
#
# epoch:  259
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541765
#
# epoch:  260
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541752
#
# epoch:  261
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541175
#
# epoch:  262
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541498
#
# epoch:  263
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541505
#
# epoch:  264
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541468
#
# epoch:  265
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541560
#
# epoch:  266
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541687
#
# epoch:  267
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541928
#
# epoch:  268
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541727
#
# epoch:  269
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541883
#
# epoch:  270
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540994
#
# epoch:  271
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540809
#
# epoch:  272
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541626
#
# epoch:  273
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542706
#
# epoch:  274
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541356
#
# epoch:  275
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541055
#
# epoch:  276
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541047
#
# epoch:  277
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541216
#
# epoch:  278
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541212
#
# epoch:  279
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.542048
#
# epoch:  280
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540975
#
# epoch:  281
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541243
#
# epoch:  282
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541132
#
# epoch:  283
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540830
#
# epoch:  284
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540896
#
# epoch:  285
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540865
#
# epoch:  286
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541014
#
# epoch:  287
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541139
#
# epoch:  288
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541609
#
# epoch:  289
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541324
#
# epoch:  290
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540868
#
# epoch:  291
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540499
#
# epoch:  292
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541746
#
# epoch:  293
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541117
#
# epoch:  294
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540926
#
# epoch:  295
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541412
#
# epoch:  296
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541540
#
# epoch:  297
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541101
#
# epoch:  298
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541676
#
# epoch:  299
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540669
#
# epoch:  300
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.540954
#
# epoch:  301
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541559
#
# epoch:  302
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541335
#
# epoch:  303
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540451
#
# epoch:  304
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541037
#
# epoch:  305
# Train Error:
#  Accuracy: 68.9%, Avg loss: 0.541794
#
# epoch:  306
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540501
#
# epoch:  307
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540766
#
# epoch:  308
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540619
#
# epoch:  309
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541301
#
# epoch:  310
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541136
#
# epoch:  311
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540574
#
# epoch:  312
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540952
#
# epoch:  313
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540149
#
# epoch:  314
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540602
#
# epoch:  315
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540042
#
# epoch:  316
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540871
#
# epoch:  317
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540684
#
# epoch:  318
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541306
#
# epoch:  319
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541435
#
# epoch:  320
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540322
#
# epoch:  321
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540665
#
# epoch:  322
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540696
#
# epoch:  323
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540564
#
# epoch:  324
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541059
#
# epoch:  325
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540508
#
# epoch:  326
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539937
#
# epoch:  327
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540076
#
# epoch:  328
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540314
#
# epoch:  329
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540592
#
# epoch:  330
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.539995
#
# epoch:  331
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540775
#
# epoch:  332
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541044
#
# epoch:  333
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540218
#
# epoch:  334
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540131
#
# epoch:  335
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540505
#
# epoch:  336
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540275
#
# epoch:  337
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541297
#
# epoch:  338
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540219
#
# epoch:  339
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540456
#
# epoch:  340
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.541122
#
# epoch:  341
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540481
#
# epoch:  342
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540381
#
# epoch:  343
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540048
#
# epoch:  344
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540332
#
# epoch:  345
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540674
#
# epoch:  346
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540200
#
# epoch:  347
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540561
#
# epoch:  348
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540154
#
# epoch:  349
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540601
#
# epoch:  350
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.541008
#
# epoch:  351
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540076
#
# epoch:  352
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540683
#
# epoch:  353
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540006
#
# epoch:  354
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539870
#
# epoch:  355
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540052
#
# epoch:  356
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540151
#
# epoch:  357
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540618
#
# epoch:  358
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540075
#
# epoch:  359
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.539759
#
# epoch:  360
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540275
#
# epoch:  361
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540694
#
# epoch:  362
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539633
#
# epoch:  363
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540078
#
# epoch:  364
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540465
#
# epoch:  365
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540490
#
# epoch:  366
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539363
#
# epoch:  367
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540005
#
# epoch:  368
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539989
#
# epoch:  369
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539510
#
# epoch:  370
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540020
#
# epoch:  371
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539836
#
# epoch:  372
# Train Error:
#  Accuracy: 69.0%, Avg loss: 0.540198
#
# epoch:  373
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540144
#
# epoch:  374
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539230
#
# epoch:  375
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539865
#
# epoch:  376
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539955
#
# epoch:  377
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539320
#
# epoch:  378
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540009
#
# epoch:  379
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539746
#
# epoch:  380
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539497
#
# epoch:  381
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539805
#
# epoch:  382
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540289
#
# epoch:  383
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539921
#
# epoch:  384
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539724
#
# epoch:  385
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540495
#
# epoch:  386
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539756
#
# epoch:  387
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540321
#
# epoch:  388
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539766
#
# epoch:  389
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.540006
#
# epoch:  390
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539947
#
# epoch:  391
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540041
#
# epoch:  392
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540400
#
# epoch:  393
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539665
#
# epoch:  394
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539686
#
# epoch:  395
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539925
#
# epoch:  396
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539910
#
# epoch:  397
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539993
#
# epoch:  398
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539747
#
# epoch:  399
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539694
#
# epoch:  400
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539957
#
# epoch:  401
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539427
#
# epoch:  402
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539427
#
# epoch:  403
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539656
#
# epoch:  404
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539356
#
# epoch:  405
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539947
#
# epoch:  406
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539642
#
# epoch:  407
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539321
#
# epoch:  408
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539034
#
# epoch:  409
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539897
#
# epoch:  410
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539042
#
# epoch:  411
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539268
#
# epoch:  412
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539814
#
# epoch:  413
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539639
#
# epoch:  414
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539485
#
# epoch:  415
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540130
#
# epoch:  416
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539036
#
# epoch:  417
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539304
#
# epoch:  418
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538774
#
# epoch:  419
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539668
#
# epoch:  420
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539026
#
# epoch:  421
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539542
#
# epoch:  422
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539050
#
# epoch:  423
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539413
#
# epoch:  424
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539093
#
# epoch:  425
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539652
#
# epoch:  426
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539266
#
# epoch:  427
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.540263
#
# epoch:  428
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539179
#
# epoch:  429
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539792
#
# epoch:  430
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539355
#
# epoch:  431
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539022
#
# epoch:  432
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.539825
#
# epoch:  433
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539194
#
# epoch:  434
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538887
#
# epoch:  435
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538918
#
# epoch:  436
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539640
#
# epoch:  437
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539362
#
# epoch:  438
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538407
#
# epoch:  439
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539122
#
# epoch:  440
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539271
#
# epoch:  441
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539529
#
# epoch:  442
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538695
#
# epoch:  443
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538542
#
# epoch:  444
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539088
#
# epoch:  445
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538781
#
# epoch:  446
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539361
#
# epoch:  447
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539439
#
# epoch:  448
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538884
#
# epoch:  449
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539258
#
# epoch:  450
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538721
#
# epoch:  451
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538849
#
# epoch:  452
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539186
#
# epoch:  453
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539140
#
# epoch:  454
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538467
#
# epoch:  455
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538940
#
# epoch:  456
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538324
#
# epoch:  457
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538655
#
# epoch:  458
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538908
#
# epoch:  459
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538667
#
# epoch:  460
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538712
#
# epoch:  461
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538631
#
# epoch:  462
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539354
#
# epoch:  463
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538860
#
# epoch:  464
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538563
#
# epoch:  465
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538808
#
# epoch:  466
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537876
#
# epoch:  467
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538686
#
# epoch:  468
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538931
#
# epoch:  469
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538647
#
# epoch:  470
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538464
#
# epoch:  471
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538693
#
# epoch:  472
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539157
#
# epoch:  473
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.539207
#
# epoch:  474
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538153
#
# epoch:  475
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538612
#
# epoch:  476
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538834
#
# epoch:  477
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538536
#
# epoch:  478
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538381
#
# epoch:  479
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538017
#
# epoch:  480
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.537992
#
# epoch:  481
# Train Error:
#  Accuracy: 69.1%, Avg loss: 0.538815
#
# epoch:  482
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538039
#
# epoch:  483
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538610
#
# epoch:  484
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538911
#
# epoch:  485
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538433
#
# epoch:  486
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538137
#
# epoch:  487
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538726
#
# epoch:  488
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538356
#
# epoch:  489
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538341
#
# epoch:  490
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538690
#
# epoch:  491
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538265
#
# epoch:  492
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538764
#
# epoch:  493
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538648
#
# epoch:  494
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538286
#
# epoch:  495
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538366
#
# epoch:  496
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539021
#
# epoch:  497
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537997
#
# epoch:  498
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538879
#
# epoch:  499
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537902
#
# epoch:  500
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538284
#
# epoch:  501
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538167
#
# epoch:  502
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538185
#
# epoch:  503
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538365
#
# epoch:  504
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.538309
#
# epoch:  505
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538245
#
# epoch:  506
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538532
#
# epoch:  507
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537899
#
# epoch:  508
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537898
#
# epoch:  509
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537920
#
# epoch:  510
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538225
#
# epoch:  511
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.537566
#
# epoch:  512
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.537691
#
# epoch:  513
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537923
#
# epoch:  514
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.537656
#
# epoch:  515
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538138
#
# epoch:  516
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538444
#
# epoch:  517
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537962
#
# epoch:  518
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.538235
#
# epoch:  519
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538317
#
# epoch:  520
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538187
#
# epoch:  521
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.537589
#
# epoch:  522
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538246
#
# epoch:  523
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538350
#
# epoch:  524
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537774
#
# epoch:  525
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538531
#
# epoch:  526
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538378
#
# epoch:  527
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538330
#
# epoch:  528
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537467
#
# epoch:  529
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.538625
#
# epoch:  530
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537247
#
# epoch:  531
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537638
#
# epoch:  532
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537312
#
# epoch:  533
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537386
#
# epoch:  534
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537861
#
# epoch:  535
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538125
#
# epoch:  536
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538199
#
# epoch:  537
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.538023
#
# epoch:  538
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537848
#
# epoch:  539
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537650
#
# epoch:  540
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537902
#
# epoch:  541
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.538142
#
# epoch:  542
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537560
#
# epoch:  543
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537480
#
# epoch:  544
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537455
#
# epoch:  545
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537645
#
# epoch:  546
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537652
#
# epoch:  547
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537964
#
# epoch:  548
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537740
#
# epoch:  549
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537760
#
# epoch:  550
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.538292
#
# epoch:  551
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537671
#
# epoch:  552
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538307
#
# epoch:  553
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.538115
#
# epoch:  554
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.539124
#
# epoch:  555
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537853
#
# epoch:  556
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537558
#
# epoch:  557
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537838
#
# epoch:  558
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537510
#
# epoch:  559
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538337
#
# epoch:  560
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537752
#
# epoch:  561
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537453
#
# epoch:  562
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.537754
#
# epoch:  563
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537689
#
# epoch:  564
# Train Error:
#  Accuracy: 69.2%, Avg loss: 0.537668
#
# epoch:  565
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.538013
#
# epoch:  566
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537131
#
# epoch:  567
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537323
#
# epoch:  568
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537392
#
# epoch:  569
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536805
#
# epoch:  570
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537088
#
# epoch:  571
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537138
#
# epoch:  572
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537231
#
# epoch:  573
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537704
#
# epoch:  574
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536586
#
# epoch:  575
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537010
#
# epoch:  576
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537383
#
# epoch:  577
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537848
#
# epoch:  578
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.538006
#
# epoch:  579
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.537349
#
# epoch:  580
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537457
#
# epoch:  581
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537400
#
# epoch:  582
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537197
#
# epoch:  583
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537311
#
# epoch:  584
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537363
#
# epoch:  585
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537179
#
# epoch:  586
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537295
#
# epoch:  587
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536934
#
# epoch:  588
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537578
#
# epoch:  589
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537463
#
# epoch:  590
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536581
#
# epoch:  591
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536997
#
# epoch:  592
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537934
#
# epoch:  593
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537724
#
# epoch:  594
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.538031
#
# epoch:  595
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537021
#
# epoch:  596
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537595
#
# epoch:  597
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537726
#
# epoch:  598
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537517
#
# epoch:  599
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536997
#
# epoch:  600
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536594
#
# epoch:  601
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537276
#
# epoch:  602
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537446
#
# epoch:  603
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537639
#
# epoch:  604
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536644
#
# epoch:  605
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537281
#
# epoch:  606
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537001
#
# epoch:  607
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536813
#
# epoch:  608
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536881
#
# epoch:  609
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537205
#
# epoch:  610
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537021
#
# epoch:  611
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537074
#
# epoch:  612
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537375
#
# epoch:  613
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.537110
#
# epoch:  614
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537089
#
# epoch:  615
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537184
#
# epoch:  616
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537311
#
# epoch:  617
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536959
#
# epoch:  618
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536752
#
# epoch:  619
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537019
#
# epoch:  620
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537103
#
# epoch:  621
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536617
#
# epoch:  622
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536554
#
# epoch:  623
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536715
#
# epoch:  624
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537231
#
# epoch:  625
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537069
#
# epoch:  626
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537251
#
# epoch:  627
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536858
#
# epoch:  628
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537287
#
# epoch:  629
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537072
#
# epoch:  630
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536891
#
# epoch:  631
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537213
#
# epoch:  632
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.537572
#
# epoch:  633
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537119
#
# epoch:  634
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536890
#
# epoch:  635
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536642
#
# epoch:  636
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536386
#
# epoch:  637
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536609
#
# epoch:  638
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536354
#
# epoch:  639
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537141
#
# epoch:  640
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536637
#
# epoch:  641
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537029
#
# epoch:  642
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535991
#
# epoch:  643
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536834
#
# epoch:  644
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537735
#
# epoch:  645
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537040
#
# epoch:  646
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536771
#
# epoch:  647
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.537362
#
# epoch:  648
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536499
#
# epoch:  649
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536484
#
# epoch:  650
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536696
#
# epoch:  651
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536337
#
# epoch:  652
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536242
#
# epoch:  653
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536182
#
# epoch:  654
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536009
#
# epoch:  655
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536192
#
# epoch:  656
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536342
#
# epoch:  657
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536627
#
# epoch:  658
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536691
#
# epoch:  659
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535880
#
# epoch:  660
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536285
#
# epoch:  661
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536329
#
# epoch:  662
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536143
#
# epoch:  663
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536553
#
# epoch:  664
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536979
#
# epoch:  665
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536092
#
# epoch:  666
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536045
#
# epoch:  667
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536358
#
# epoch:  668
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536846
#
# epoch:  669
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536792
#
# epoch:  670
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536907
#
# epoch:  671
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536776
#
# epoch:  672
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536207
#
# epoch:  673
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535979
#
# epoch:  674
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536421
#
# epoch:  675
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536357
#
# epoch:  676
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537246
#
# epoch:  677
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536030
#
# epoch:  678
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536273
#
# epoch:  679
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536662
#
# epoch:  680
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536164
#
# epoch:  681
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536599
#
# epoch:  682
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536221
#
# epoch:  683
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.537427
#
# epoch:  684
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536021
#
# epoch:  685
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535976
#
# epoch:  686
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535474
#
# epoch:  687
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536243
#
# epoch:  688
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536062
#
# epoch:  689
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536104
#
# epoch:  690
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535878
#
# epoch:  691
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536035
#
# epoch:  692
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536497
#
# epoch:  693
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535966
#
# epoch:  694
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536051
#
# epoch:  695
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536107
#
# epoch:  696
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536222
#
# epoch:  697
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536234
#
# epoch:  698
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536285
#
# epoch:  699
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536272
#
# epoch:  700
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536616
#
# epoch:  701
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535589
#
# epoch:  702
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535877
#
# epoch:  703
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536693
#
# epoch:  704
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536024
#
# epoch:  705
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536397
#
# epoch:  706
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536464
#
# epoch:  707
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536406
#
# epoch:  708
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536207
#
# epoch:  709
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536206
#
# epoch:  710
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536043
#
# epoch:  711
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536316
#
# epoch:  712
# Train Error:
#  Accuracy: 69.3%, Avg loss: 0.536150
#
# epoch:  713
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536095
#
# epoch:  714
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536485
#
# epoch:  715
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535691
#
# epoch:  716
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535800
#
# epoch:  717
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536671
#
# epoch:  718
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536415
#
# epoch:  719
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536770
#
# epoch:  720
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536344
#
# epoch:  721
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535767
#
# epoch:  722
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535996
#
# epoch:  723
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536300
#
# epoch:  724
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535870
#
# epoch:  725
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.536216
#
# epoch:  726
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536349
#
# epoch:  727
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536295
#
# epoch:  728
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535816
#
# epoch:  729
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535652
#
# epoch:  730
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536324
#
# epoch:  731
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535805
#
# epoch:  732
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535487
#
# epoch:  733
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535764
#
# epoch:  734
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536411
#
# epoch:  735
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536582
#
# epoch:  736
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535666
#
# epoch:  737
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535927
#
# epoch:  738
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.535358
#
# epoch:  739
# Train Error:
# ...
#
# epoch:  754
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.536309
#
# epoch:  755
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.535521
#
# epoch:  756
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535638
#
# epoch:  757
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535348
#
# epoch:  758
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535854
#
# epoch:  759
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535972
#
# epoch:  760
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535354
#
# epoch:  761
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535344
#
# epoch:  762
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535798
#
# epoch:  763
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535795
#
# epoch:  764
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535145
#
# epoch:  765
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535476
#
# epoch:  766
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535595
#
# epoch:  767
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535724
#
# epoch:  768
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535678
#
# epoch:  769
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535884
#
# epoch:  770
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535186
#
# epoch:  771
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.535768
#
# epoch:  772
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535601
#
# epoch:  773
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535724
#
# epoch:  774
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.534772
#
# epoch:  775
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535282
#
# epoch:  776
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535268
#
# epoch:  777
# Train Error:
#  Accuracy: 69.4%, Avg loss: 0.535660
#
# epoch:  778
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535585
#
# epoch:  779
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535627
#
# epoch:  780
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535689
#
# epoch:  781
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535641
#
# epoch:  782
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535771
#
# epoch:  783
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535403
#
# epoch:  784
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535878
#
# epoch:  785
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535486
#
# epoch:  786
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535104
#
# epoch:  787
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535033
#
# epoch:  788
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535502
#
# epoch:  789
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.535655
#
# epoch:  790
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535185
#
# epoch:  791
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535326
#
# epoch:  792
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535669
#
# epoch:  793
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535365
#
# epoch:  794
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535324
#
# epoch:  795
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535274
#
# epoch:  796
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535213
#
# epoch:  797
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535913
#
# epoch:  798
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535113
#
# epoch:  799
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535418
#
# epoch:  800
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535089
#
# epoch:  801
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535057
#
# epoch:  802
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535068
#
# epoch:  803
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534807
#
# epoch:  804
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535489
#
# epoch:  805
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535054
#
# epoch:  806
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535287
#
# epoch:  807
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535327
#
# epoch:  808
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535039
#
# epoch:  809
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535589
#
# epoch:  810
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535085
#
# epoch:  811
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536187
#
# epoch:  812
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535180
#
# epoch:  813
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534773
#
# epoch:  814
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535490
#
# epoch:  815
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535340
#
# epoch:  816
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535260
#
# epoch:  817
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534943
#
# epoch:  818
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535020
#
# epoch:  819
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536028
#
# epoch:  820
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535250
#
# epoch:  821
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535625
#
# epoch:  822
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535299
#
# epoch:  823
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535232
#
# epoch:  824
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534971
#
# epoch:  825
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535200
#
# epoch:  826
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535481
#
# epoch:  827
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534581
#
# epoch:  828
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535058
#
# epoch:  829
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.536075
#
# epoch:  830
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534873
#
# epoch:  831
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535341
#
# epoch:  832
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535414
#
# epoch:  833
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535161
#
# epoch:  834
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534839
#
# epoch:  835
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535148
#
# epoch:  836
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535407
#
# epoch:  837
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.535375
#
# epoch:  838
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535245
#
# epoch:  839
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534948
#
# epoch:  840
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535207
#
# epoch:  841
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534958
#
# epoch:  842
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534791
#
# epoch:  843
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.535356
#
# epoch:  844
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535606
#
# epoch:  845
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535067
#
# epoch:  846
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535264
#
# epoch:  847
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535314
#
# epoch:  848
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534914
#
# epoch:  849
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535273
#
# epoch:  850
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534858
#
# epoch:  851
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535115
#
# epoch:  852
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535822
#
# epoch:  853
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535038
#
# epoch:  854
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535157
#
# epoch:  855
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534678
#
# epoch:  856
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534724
#
# epoch:  857
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535259
#
# epoch:  858
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534506
#
# epoch:  859
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535617
#
# epoch:  860
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534299
#
# epoch:  861
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534857
#
# epoch:  862
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534753
#
# epoch:  863
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535408
#
# epoch:  864
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534844
#
# epoch:  865
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534736
#
# epoch:  866
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.534820
#
# epoch:  867
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.535183
#
# epoch:  868
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534732
#
# epoch:  869
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534949
#
# epoch:  870
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534721
#
# epoch:  871
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535283
#
# epoch:  872
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534774
#
# epoch:  873
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534291
#
# epoch:  874
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534337
#
# epoch:  875
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535106
#
# epoch:  876
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534598
#
# epoch:  877
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534102
#
# epoch:  878
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535062
#
# epoch:  879
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535369
#
# epoch:  880
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535011
#
# epoch:  881
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534694
#
# epoch:  882
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535185
#
# epoch:  883
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534965
#
# epoch:  884
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534558
#
# epoch:  885
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535073
#
# epoch:  886
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534955
#
# epoch:  887
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534126
#
# epoch:  888
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534417
#
# epoch:  889
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534764
#
# epoch:  890
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534302
#
# epoch:  891
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534875
#
# epoch:  892
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534723
#
# epoch:  893
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535417
#
# epoch:  894
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535063
#
# epoch:  895
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534571
#
# epoch:  896
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534880
#
# epoch:  897
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535231
#
# epoch:  898
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534763
#
# epoch:  899
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534876
#
# epoch:  900
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534765
#
# epoch:  901
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534669
#
# epoch:  902
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535275
#
# epoch:  903
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535198
#
# epoch:  904
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534436
#
# epoch:  905
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534419
#
# epoch:  906
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534844
#
# epoch:  907
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534725
#
# epoch:  908
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534017
#
# epoch:  909
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534616
#
# epoch:  910
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534194
#
# epoch:  911
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.534554
#
# epoch:  912
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534961
#
# epoch:  913
# Train Error:
#  Accuracy: 69.8%, Avg loss: 0.534866
#
# epoch:  914
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534567
#
# epoch:  915
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534097
#
# epoch:  916
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534451
#
# epoch:  917
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535070
#
# epoch:  918
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534304
#
# epoch:  919
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534117
#
# epoch:  920
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534842
#
# epoch:  921
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.534315
#
# epoch:  922
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534466
#
# epoch:  923
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534472
#
# epoch:  924
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534188
#
# epoch:  925
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534222
#
# epoch:  926
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534932
#
# epoch:  927
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534355
#
# epoch:  928
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534794
#
# epoch:  929
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.534797
#
# epoch:  930
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534898
#
# epoch:  931
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534101
#
# epoch:  932
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534592
#
# epoch:  933
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535029
#
# epoch:  934
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534748
#
# epoch:  935
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534839
#
# epoch:  936
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534341
#
# epoch:  937
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534746
#
# epoch:  938
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.535166
#
# epoch:  939
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534153
#
# epoch:  940
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534191
#
# epoch:  941
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534335
#
# epoch:  942
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534311
#
# epoch:  943
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534171
#
# epoch:  944
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.533998
#
# epoch:  945
# Train Error:
#  Accuracy: 69.8%, Avg loss: 0.534970
#
# epoch:  946
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534579
#
# epoch:  947
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534360
#
# epoch:  948
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534171
#
# epoch:  949
# Train Error:
#  Accuracy: 69.8%, Avg loss: 0.534605
#
# epoch:  950
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534800
#
# epoch:  951
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534523
#
# epoch:  952
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534445
#
# epoch:  953
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534849
#
# epoch:  954
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534217
#
# epoch:  955
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.533945
#
# epoch:  956
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534209
#
# epoch:  957
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.535544
#
# epoch:  958
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534555
#
# epoch:  959
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534252
#
# epoch:  960
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534304
#
# epoch:  961
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534897
#
# epoch:  962
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534412
#
# epoch:  963
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534591
#
# epoch:  964
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.533667
#
# epoch:  965
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534783
#
# epoch:  966
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534161
#
# epoch:  967
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534835
#
# epoch:  968
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534500
#
# epoch:  969
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535308
#
# epoch:  970
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534315
#
# epoch:  971
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534009
#
# epoch:  972
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.533852
#
# epoch:  973
# Train Error:
#  Accuracy: 69.8%, Avg loss: 0.534720
#
# epoch:  974
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534542
#
# epoch:  975
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534291
#
# epoch:  976
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534057
#
# epoch:  977
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534047
#
# epoch:  978
# Train Error:
#  Accuracy: 69.8%, Avg loss: 0.533770
#
# epoch:  979
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534112
#
# epoch:  980
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.533859
#
# epoch:  981
# Train Error:
#  Accuracy: 69.8%, Avg loss: 0.533769
#
# epoch:  982
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534358
#
# epoch:  983
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534984
#
# epoch:  984
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.533937
#
# epoch:  985
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534661
#
# epoch:  986
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534723
#
# epoch:  987
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534597
#
# epoch:  988
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.534471
#
# epoch:  989
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.535094
#
# epoch:  990
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.533974
#
# epoch:  991
# Train Error:
#  Accuracy: 69.5%, Avg loss: 0.534290
#
# epoch:  992
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534218
#
# epoch:  993
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.533908
#
# epoch:  994
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.533880
#
# epoch:  995
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534339
#
# epoch:  996
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.533959
#
# epoch:  997
# Train Error:
#  Accuracy: 69.6%, Avg loss: 0.533991
#
# epoch:  998
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534247
#
# epoch:  999
# Train Error:
#  Accuracy: 69.7%, Avg loss: 0.534982
